# %%
import fastf1 as ff1
from fastf1 import plotting
from matplotlib import pyplot as plt
from matplotlib.pyplot import figure
from matplotlib.collections import LineCollection
from matplotlib import cm
import numpy as np
import pandas as pd
import json

# %%
# Enable the cache
ff1.Cache.enable_cache('cache')

# %%
# Load the session data
race = ff1.get_session(2021, 'Abu Dhabi', 'R')

# Get the laps
laps = race.load_laps(with_telemetry=False)
# Out:
# core           INFO 	Loading laps for Abu Dhabi Grand Prix - Race [v2.1.12]
# api            INFO 	Using cached data for timing_data
# api            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# api            INFO 	Using cached data for driver_info
# api            INFO 	Using cached data for session_status_data
# utils          INFO 	Note: NumExpr detected 24 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# utils          INFO 	NumExpr defaulting to 8 threads.
# api            INFO 	Using cached data for track_status_data
# api            INFO 	Using cached data for weather_data
# core           INFO 	Loaded data for 19 drivers: ['33', '44', '4', '11', '55', '77', '16', '22', '31', '3', '14', '10', '18', '99', '5', '6', '63', '7', '47']

# %%
# Calculate RaceLapNumber (LapNumber minus 1 since the warmup lap is included in LapNumber)
laps['RaceLapNumber'] = laps['LapNumber'] - 1

# %%
# Get all drivers
drivers = pd.DataFrame(laps['Driver'].unique())

# telemetry = pd.DataFrame()

# # Telemetry can only be retrieved driver-by-driver
# for driver in drivers:
#     driver_laps = laps.pick_driver(driver)
    
#     # Since we want to compare distances, we need to collect telemetry lap-by-lap to reset the distance
#     for lap in driver_laps.iterlaps():
#         driver_telemetry = lap[1].get_telemetry().add_distance()
#         driver_telemetry['Driver'] = driver
#         driver_telemetry['Lap'] = lap[1]['RaceLapNumber']
#         driver_telemetry['Compound'] = lap[1]['Compound']
    
#         telemetry = telemetry.append(driver_telemetry)

# %%
laps['Time'] = laps['Time'].dt.total_seconds().round(decimals = 3)
laps['LapTime'] = laps['LapTime'].dt.total_seconds().round(decimals = 3)
laps['PitOutTime'] = laps['PitOutTime'].dt.total_seconds().round(decimals = 3)
laps['PitInTime'] = laps['PitInTime'].dt.total_seconds().round(decimals = 3)
laps['Sector1Time'] = laps['Sector1Time'].dt.total_seconds().round(decimals = 3)
laps['Sector2Time'] = laps['Sector2Time'].dt.total_seconds().round(decimals = 3)
laps['Sector3Time'] = laps['Sector3Time'].dt.total_seconds().round(decimals = 3)
laps['Sector1SessionTime'] = laps['Sector1SessionTime'].dt.total_seconds().round(decimals = 3)
laps['Sector2SessionTime'] = laps['Sector2SessionTime'].dt.total_seconds().round(decimals = 3)
laps['Sector3SessionTime'] = laps['Sector3SessionTime'].dt.total_seconds().round(decimals = 3)
laps['LapStartTime'] = laps['LapStartTime'].dt.total_seconds().round(decimals = 3)

# %%
laps = laps[['Driver', 'DriverNumber', 'Team', 'RaceLapNumber',
             'LapTime', 'Sector1Time', 'Sector2Time', 'Sector3Time',
             'Compound', 'Stint', 'TyreLife', 'PitOutTime', 'PitInTime',
             'Time', 'TrackStatus', 'IsAccurate']]

# %%
lap_data = laps.to_dict('records')

# %%
print(lap_data)
# Out:
# [{'Driver': 'VER', 'DriverNumber': '33', 'Team': 'Red Bull', 'RaceLapNumber': 0, 'LapTime': nan, 'Sector1Time': nan, 'Sector2Time': 38.428000000000004, 'Sector3Time': 33.563, 'Compound': 'SOFT', 'Stint': 1, 'TyreLife': 4.0, 'PitOutTime': 1381.4920000000002, 'PitInTime': nan, 'Time': 3834.885, 'TrackStatus': '1', 'IsAccurate': False}, {'Driver': 'VER', 'DriverNumber': '33', 'Team': 'Red Bull', 'RaceLapNumber': 1, 'LapTime': 89.10300000000001, 'Sector1Time': 18.116, 'Sector2Time': 38.026, 'Sector3Time': 32.961, 'Compound': 'SOFT', 'Stint': 1, 'TyreLife': 5.0, 'PitOutTime': nan, 'PitInTime': nan, 'Time': 3923.9880000000003, 'TrackStatus': '1', 'IsAccurate': True}, {'Driver': 'VER', 'DriverNumber': '33', 'Team': 'Red Bull', 'RaceLapNumber': 2, 'LapTime': 88.82700000000001, 'Sector1Time': 17.999000000000002, 'Sector2Time': 38.043, 'Sector3Time': 32.785000000000004, 'Compound': 'SOFT', 'Stint': 1, 'TyreLife': 6.0, 'PitOutTime': nan, 'PitInTime': nan, 'Time': 4012.815, 'TrackStatus': '1', 'IsAccurate': True}, {'Driver': 'VER', 'DriverNumber': '33', 'Team': 'Red Bull', 'RaceLapNumber': 3, 'LapTime': 89.02600000000001, 'Sector1Time': 18.019000000000002, 'Sector2Time': 38.125, 'Sector3Time': 32.882000000000005, 'Compound': 'SOFT', 'Stint': 1, 'TyreLife': 7.0, 'PitOutTime': nan, 'PitInTime': nan, 'Time': 4101.841, 'TrackStatus': '1', 'IsAccurate': True}, {'Driver': 'VER', 'DriverNumber': '33', 'Team': 'Red Bull', 'RaceLapNumber': 4, 'LapTime': 88.718, 'Sector1Time': 17.999000000000002, 'Sector2Time': 38.083000000000006, 'Sector3Time': 32.636, 'Compound': 'SOFT', 'Stint': 1, 'TyreLife': 8.0, 'PitOutTime': nan, 'PitInTime': nan, 'Time': 4190.559, 'TrackStatus': '1', 'IsAccurate': True}, {'Driver': 'VER', 'DriverNumber': '33', 'Team': 'Red Bull', 'RaceLapNumber': 5, 'LapTime': 88.70700000000001, 'Sector1Time': 17.958000000000002, 'Sector2Time': 38.014, 'Sector3Time': 32.735, 'Compound': 'SOFT', 'Stint': 1, 'TyreLife': 9.0, 'PitOutTime': nan, 'PitInTime': nan, 'Time': 4279.2660000000005, 'TrackStatus': '1', 'IsAccurate': True}, {'Driver': 'VER', 'DriverNumber': '33', 'Team': 'Red Bull', 'RaceLapNumber': 6, 'LapTime': 88.63600000000001, 'Sector1Time': 18.0, 'Sector2Time': 38.046, 'Sector3Time': 32.59, 'Compound': 'SOFT', 'Stint': 1, 'TyreLife': 10.0, 'PitOutTime': nan, 'PitInTime': nan, 'Time': 4367.902, 'TrackStatus': '1', 'IsAccurate': True}, {'Driver': 'VER', 'DriverNumber': '33', 'Team': 'Red Bull', 'RaceLapNumber': 7, 'LapTime': 88.81700000000001, 'Sector1Time': 18.064, 'Sector2Time': 38.188, 'Sector3Time': 32.565000000000005, 'Compound': 'SOFT', 'Stint': 1, 'TyreLife': 11.0, 'PitOutTime': nan, 'PitInTime': nan, 'Time': 4456.719, 'TrackStatus': '1', 'IsAccurate': True}, {'Driver': 'VER', 'DriverNumber': '33', 'Team': 'Red Bull', 'RaceLapNumber': 8, 'LapTime': 88.671, 'Sector1Time': 18.022000000000002, 'Sector2Time': 38.197, 'Sector3Time': 32.452000000000005, 'Compound': 'SOFT', 'Stint': 1, 'TyreLife': 12.0, 'PitOutTime': nan, 'PitInTime': nan, 'Time': 4545.39, 'TrackStatus': '1', 'IsAccurate': True}, {'Driver': 'VER', 'DriverNumber': '33', 'Team': 'Red Bull', 'RaceLapNumber': 9, 'LapTime': 88.89, 'Sector1Time': 18.025000000000002, 'Sector2Time': 38.207, 'Sector3Time': 32.658, 'Compound': 'SOFT', 'Stint': 1, 'TyreLife': 13.0, 'PitOutTime': nan, 'PitInTime': nan, 'Time': 4634.280000000001, 'TrackStatus': '1', 'IsAccurate': True}, {'Driver': 'VER', 'DriverNumber': '33', 'Team': 'Red Bull', 'RaceLapNumber': 10, 'LapTime': 89.137, 'Sector1Time': 18.122, 'Sector2Time': 38.378, 'Sector3Time': 32.637, 'Compound': 'SOFT', 'Stint': 1, 'TyreLife': 14.0, 'PitOutTime': nan, 'PitInTime': nan, 'Time': 4723.417, 'TrackStatus': '1', 'IsAccurate': True}, {'Driver': 'VER', 'DriverNumber': '33', 'Team': 'Red Bull', 'RaceLapNumber': 11, 'LapTime': 89.28200000000001, 'Sector1Time': 18.186, 'Sector2Time': 38.25, 'Sector3Time': 32.846000000000004, 'Compound': 'SOFT', 'Stint': 1, 'TyreLife': 15.0, 'PitOutTime': nan, 'PitInTime': nan, 'Time': 4812.6990000000005,  ...
